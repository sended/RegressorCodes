# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_absolute_error, median_absolute_error, mean_squared_log_error, \
mean_squared_error
from sklearn.model_selection import GridSearchCV, cross_validate, train_test_split
# %matplotlib inline

# %%
preditors = pd.read_csv('kc_house_data.csv')
preditors.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
target = preditors.price
preditors.drop(['price', 'sqft_lot15', 'zipcode', 'yr_built', 'yr_renovated', 'condition', 'view', 'floors',
                'bathrooms', 'bedrooms', 'date', 'sqft_basement'], axis=1, inplace=True)

# %%
parameters = {'n_estimators':[10, 20, 40, 100, 400],'max_depth':[None, 6]}
forest = RandomForestRegressor()
grid = GridSearchCV(estimator=forest, param_grid=parameters, cv=4, n_jobs=-1)
grid.fit(preditors, target)
# Out:
# GridSearchCV(cv=4, error_score='raise-deprecating',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=-1,
#        param_grid={'n_estimators': [10, 20, 40, 100, 400], 'max_depth': [None, 6]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
print(pd.DataFrame(grid.cv_results_))
print('-'*50, end='')
print('best parameters', end='')
print('-'*50)
print(grid.best_params_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.980377      0.050471         0.013962    3.526258e-07
# 1       1.969730      0.077353         0.028175    1.915251e-03
# 2       3.796844      0.088895         0.052360    2.864053e-03
# 3       9.408586      0.019964         0.130152    1.653987e-03
# 4      30.035169      0.180208         0.409655    1.382484e-02
# 5       0.337846      0.004425         0.004239    4.318457e-04
# 6       0.676690      0.009527         0.007480    4.990697e-04
# 7       1.340165      0.019305         0.013464    8.637947e-04
# 8       3.355276      0.036388         0.030668    1.295847e-03
# 9      11.457106      0.184504         0.100232    7.900682e-03
#
#   param_max_depth param_n_estimators  \
# 0            None                 10
# 1            None                 20
# 2            None                 40
# 3            None                100
# 4            None                400
# 5               6                 10
# 6               6                 20
# 7               6                 40
# 8               6                100
# 9               6                400
#
#                                      params  split0_test_score  \
# 0   {'max_depth': None, 'n_estimators': 10}           0.855372
# 1   {'max_depth': None, 'n_estimators': 20}           0.869683
# 2   {'max_depth': None, 'n_estimators': 40}           0.875696
# 3  {'max_depth': None, 'n_estimators': 100}           0.875202
# 4  {'max_depth': None, 'n_estimators': 400}           0.878716
# 5      {'max_depth': 6, 'n_estimators': 10}           0.805339
# 6      {'max_depth': 6, 'n_estimators': 20}           0.811882
# 7      {'max_depth': 6, 'n_estimators': 40}           0.810654
# 8     {'max_depth': 6, 'n_estimators': 100}           0.812343
# 9     {'max_depth': 6, 'n_estimators': 400}           0.813113
#
#    split1_test_score  split2_test_score  split3_test_score  mean_test_score  \
# 0           0.867203           0.827223           0.861284         0.852771
# 1           0.879300           0.832002           0.862929         0.860979
# 2           0.883277           0.833993           0.868801         0.865442
# 3           0.877412           0.841184           0.870616         0.866104
# 4           0.880931           0.842334           0.872508         0.868623
# 5           0.810009           0.756996           0.783325         0.788918
# 6           0.803279           0.751669           0.787610         0.788611
# 7           0.815425           0.748982           0.800305         0.793843
# 8           0.812649           0.758568           0.796306         0.794967
# 9           0.812171           0.757649           0.796659         0.794899
#
#    std_test_score  rank_test_score  split0_train_score  split1_train_score  \
# 0        0.015331                5            0.976316            0.973840
# 1        0.017712                4            0.977704            0.978123
# 2        0.018864                3            0.980040            0.979679
# 3        0.014594                2            0.982088            0.981518
# 4        0.015488                1            0.982589            0.981953
# 5        0.021005                9            0.833889            0.836175
# 6        0.023035               10            0.837338            0.834741
# 7        0.026470                8            0.838167            0.840113
# 8        0.022030                6            0.840082            0.838976
# 9        0.022476                7            0.840300            0.838448
#
#    split2_train_score  split3_train_score  mean_train_score  std_train_score
# 0            0.973353            0.973162          0.974168         0.001265
# 1            0.980380            0.976323          0.978133         0.001459
# 2            0.981171            0.977726          0.979654         0.001242
# 3            0.982629            0.980438          0.981668         0.000812
# 4            0.983541            0.980626          0.982177         0.001059
# 5            0.845006            0.829356          0.836106         0.005694
# 6            0.844841            0.832389          0.837327         0.004678
# 7            0.845782            0.831759          0.838955         0.005009
# 8            0.847782            0.833626          0.840116         0.005054
# 9            0.848104            0.834802          0.840413         0.004861
# --------------------------------------------------best parameters--------------------------------------------------
# {'max_depth': None, 'n_estimators': 400}
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split3_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)

# %%
forest = RandomForestRegressor(n_estimators=400, n_jobs=-1)
cross_validate(estimator=forest, X= preditors, y= target, cv=4)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# {'fit_time': array([3.74765706, 3.73002219, 3.73002291, 3.72005057]),
#  'score_time': array([0.1082592 , 0.10650802, 0.10491467, 0.10519266]),
#  'test_score': array([0.87712571, 0.8820305 , 0.84403177, 0.87211314]),
#  'train_score': array([0.98282102, 0.98198868, 0.98328267, 0.98027582])}

# %%
Xtr, Xts, Ytr, Yts = train_test_split(preditors, target, test_size=0.2)

# %%
forest = RandomForestRegressor(n_estimators=400, n_jobs=-1)
forest.fit(Xtr, Ytr)
predict = forest.predict(Xts)
print(mean_absolute_error(Yts, predict), '\b$')
print(mean_squared_error(Yts, predict), '$ ^ 2')
print(mean_squared_log_error(Yts, predict), 'log$')
print(median_absolute_error(Yts, predict), '\b$')
# Out:
# $
# 16154932422.825459 $ ^ 2
# 0.03271858892784099 log$
# $
